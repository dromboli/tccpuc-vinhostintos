# %% [markdown]
# ### Etapas iniciais: importação de pacotes, definição de funções, carregamento de dados

# %%
import pandas as pd

# %%
def values_missing(df, only_missing=True):
    '''Calcula e retorna o percentual e o número de registros nulos no dataframe df'''
    missing = pd.concat({'percent_missing': 100* df.isnull().sum() / len(df),
                         'rows_missing': df.isnull().sum()}, axis=1)
    if only_missing:
        missing = missing[missing.percent_missing > 0]
    return missing.sort_values(by='percent_missing', ascending=False)

# %%
# Carregamento dos datasets
vivino_wines = pd.read_csv('datasets/vivino_wines.csv')
vivino_vintages = pd.read_csv('datasets/vivino_vintages.csv')

# %% [markdown]
# ## Dataset: Vivino Wines

# %%
# Dataset com os dados de vinhos
vivino_wines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343176 entries, 0 to 343175
# Data columns (total 18 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               343176 non-null  int64
#  1   full_name        343176 non-null  object
#  2   name             343175 non-null  object
#  3   type_id          343176 non-null  int64
#  4   type             343176 non-null  object
#  5   wine_region      343176 non-null  object
#  6   winery           343176 non-null  object
#  7   winery_region    343176 non-null  object
#  8   country          343176 non-null  object
#  9   ratings_count    343176 non-null  int64
#  10  ratings_average  343176 non-null  float64
#  11  alcohol          343176 non-null  float64
#  12  acidity          343176 non-null  float64
#  13  fizziness        20842 non-null   float64
#  14  intensity        343176 non-null  float64
#  15  sweetness        322335 non-null  float64
#  16  tannin           210600 non-null  float64
#  17  url              343176 non-null  object
# dtypes: float64(7), int64(3), object(8)
# memory usage: 47.1+ MB

# %% [markdown]
# ### Filtragem
# - O dataset originalmente continha 343.176 registros, os quais cobriam diversos tipos/categorias, como vinhos brancos, espumantes e tintos. Como o trabalho restringe-se a vinhos tintos, nessa etapa foram filtrados apenas os vinhos dessa categoria resultando em 210.432 registros.

# %%
vivino_wines = vivino_wines[vivino_wines['type_id'] == 1]

# %%
vivino_wines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 210432 entries, 1 to 343175
# Data columns (total 18 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               210432 non-null  int64
#  1   full_name        210432 non-null  object
#  2   name             210431 non-null  object
#  3   type_id          210432 non-null  int64
#  4   type             210432 non-null  object
#  5   wine_region      210432 non-null  object
#  6   winery           210432 non-null  object
#  7   winery_region    210432 non-null  object
#  8   country          210432 non-null  object
#  9   ratings_count    210432 non-null  int64
#  10  ratings_average  210432 non-null  float64
#  11  alcohol          210432 non-null  float64
#  12  acidity          210432 non-null  float64
#  13  fizziness        9 non-null       float64
#  14  intensity        210432 non-null  float64
#  15  sweetness        210424 non-null  float64
#  16  tannin           210390 non-null  float64
#  17  url              210432 non-null  object
# dtypes: float64(7), int64(3), object(8)
# memory usage: 30.5+ MB

# %% [markdown]
# ### Tratamento de dados duplicados
# - Foram encontrados e removidos 1.666 registros inteiramente duplicados.
# - Após isso verificou-se a existencia de 1.370 registros duplicados pelo campo **full_name**. Ao analisar pontualmente os registros duplicados, acessando também as páginas correspondentes aos vinho no site do Vivino, pode-se perceber que que os vinhos estão duplicados no site do Vivino, sendo que em alguns casos ao acessar uma das urls é feito o redirecionamento da página para a outra, indicando possivelmente tratar-se de um registro ser o da atual e o outro um antigo. Desta forma optou-se por manter apenas o registro com maior número de análises feitas pelos usuários (**ratings_count**), por entender que o registro com maior número de avaliações é o mais atual. Os 1.370 foram removidos com a aplicação desse entendimento.

# %%
# Remoção de registros inteiramente duplicados
print('vivino_wines: Foram encontrados {} registros inteiramente duplicados'.format(vivino_wines.duplicated().sum()))

vivino_wines = vivino_wines.drop_duplicates()
print('Total de registros após a remoção dos registro duplicados: {}'.format(vivino_wines.shape[0]))
# Out:
# vivino_wines: Foram encontrados 1666 registros inteiramente duplicados
# Total de registros após a remoção dos registro duplicados: 208766

# %%
# Registros duplicados pelo **full_name**
vivino_wines[ vivino_wines.duplicated(subset=['full_name'], keep=False) ].sort_values(by='full_name').tail(50)
# Out:
#              id                                          full_name  \
# 2445       6876  Windstream - Windbreak Sarmento Vineyard Pinot...
# 172429  2318402  Windstream - Windbreak Sarmento Vineyard Pinot...
# 59214   1407923  Windstream - Windbreak Sarmento Vineyard Pinot...
# 69060   1487150                              Wine Spots Pinot Noir
# 327087  6421614                              Wine Spots Pinot Noir
# 118387  1841270     Wine X Sam - Sam Plunkett The Victorian Shiraz
# 98728   1670079     Wine X Sam - Sam Plunkett The Victorian Shiraz
# 246457  4162754              Winemaker's Choice Cabernet Sauvignon
# 264453  4625465              Winemaker's Choice Cabernet Sauvignon
# 242240  3993163                          Winemaker's Choice Malbec
# 311733  6100483                          Winemaker's Choice Malbec
# 9999    1233986  Wines That Rock Pink Floyd's The Dark Side of ...
# 149109  2092458  Wines That Rock Pink Floyd's The Dark Side of ...
# 224677  1152892                                 Winking Owl Shiraz
# 245179  4112346                                 Winking Owl Shiraz
# 93333   1627327                        Witchery Cabernet Sauvignon
# 172113  2314348                        Witchery Cabernet Sauvignon
# 152801  2141323                     Wm Morrison Cabernet Sauvignon
# 144303  2032031                     Wm Morrison Cabernet Sauvignon
# 285619  5392282                     Wm Morrison Cabernet Sauvignon
# 296024  5544230                     Wm Morrison Cabernet Sauvignon
# 313416  6168555                             Wm Morrison Pinot Noir
# 138590  1976913                             Wm Morrison Pinot Noir
# 134927  1940306                                 Wm Morrison Shiraz
# 269515  4851753                                 Wm Morrison Shiraz
# 108435  1753568                                 Wm Morrison Shiraz
# 239757  3910891                                  Wm Morrison Tinto
# 288068  5471322                                  Wm Morrison Tinto
# 244529  4087551           Wolf Blass Blass Noir Cabernet Sauvignon
# 240670  3952288           Wolf Blass Blass Noir Cabernet Sauvignon
# 169404  2282769                   Wolf Blass Gold Label Pinot Noir
# 165851  1130044                   Wolf Blass Gold Label Pinot Noir
# 165867  1130075                       Wolf Blass Grey Label Shiraz
# 339877  6910550                       Wolf Blass Grey Label Shiraz
# 57836   1395676                   Wolfgang Puck Cabernet Sauvignon
# 94430   1636158                   Wolfgang Puck Cabernet Sauvignon
# 172785  2322210                              Woodenhead Pinot Noir
# 54512   1371075                              Woodenhead Pinot Noir
# 32126   1261342                              Woodenhead Pinot Noir
# 241818  3981840                              Woodenhead Pinot Noir
# 248411  4235931                         Xanthos Cabernet Sauvignon
# 12400   7116403                         Xanthos Cabernet Sauvignon
# 223193  3308946                                      Xanthos Syrah
# 21787   7509047                                      Xanthos Syrah
# 243568  4039842                                   Ziata Pinot Noir
# 199020  1142621                                   Ziata Pinot Noir
# 145775  2046503      Zilzie Wines The Wine Press Series Pinot Noir
# 300487  5711914      Zilzie Wines The Wine Press Series Pinot Noir
# 157659  2203665                                  l'Arca Pinot Noir
# 39438   8549704                                  l'Arca Pinot Noir
#
#                                                      name  type_id      type  \
# 2445                         Sarmento Vineyard Pinot Noir        1  Red Wine
# 172429                       Sarmento Vineyard Pinot Noir        1  Red Wine
# 59214                        Sarmento Vineyard Pinot Noir        1  Red Wine
# 69060                                          Pinot Noir        1  Red Wine
# 327087                                         Pinot Noir        1  Red Wine
# 118387                               The Victorian Shiraz        1  Red Wine
# 98728                                The Victorian Shiraz        1  Red Wine
# 246457                                 Cabernet Sauvignon        1  Red Wine
# 264453                                 Cabernet Sauvignon        1  Red Wine
# 242240                                             Malbec        1  Red Wine
# 311733                                             Malbec        1  Red Wine
# 9999    Pink Floyd's The Dark Side of the Moon Caberne...        1  Red Wine
# 149109  Pink Floyd's The Dark Side of the Moon Caberne...        1  Red Wine
# 224677                                             Shiraz        1  Red Wine
# 245179                                             Shiraz        1  Red Wine
# 93333                                  Cabernet Sauvignon        1  Red Wine
# 172113                                 Cabernet Sauvignon        1  Red Wine
# 152801                                 Cabernet Sauvignon        1  Red Wine
# 144303                                 Cabernet Sauvignon        1  Red Wine
# 285619                                 Cabernet Sauvignon        1  Red Wine
# 296024                                 Cabernet Sauvignon        1  Red Wine
# 313416                                         Pinot Noir        1  Red Wine
# 138590                                         Pinot Noir        1  Red Wine
# 134927                                             Shiraz        1  Red Wine
# 269515                                             Shiraz        1  Red Wine
# 108435                                             Shiraz        1  Red Wine
# 239757                                              Tinto        1  Red Wine
# 288068                                              Tinto        1  Red Wine
# 244529                      Blass Noir Cabernet Sauvignon        1  Red Wine
# 240670                      Blass Noir Cabernet Sauvignon        1  Red Wine
# 169404                              Gold Label Pinot Noir        1  Red Wine
# 165851                              Gold Label Pinot Noir        1  Red Wine
# 165867                                  Grey Label Shiraz        1  Red Wine
# 339877                                  Grey Label Shiraz        1  Red Wine
# 57836                                  Cabernet Sauvignon        1  Red Wine
# 94430                                  Cabernet Sauvignon        1  Red Wine
# 172785                                         Pinot Noir        1  Red Wine
# 54512                                          Pinot Noir        1  Red Wine
# 32126                                          Pinot Noir        1  Red Wine
# 241818                                         Pinot Noir        1  Red Wine
# 248411                                 Cabernet Sauvignon        1  Red Wine
# 12400                                  Cabernet Sauvignon        1  Red Wine
# 223193                                              Syrah        1  Red Wine
# 21787                                               Syrah        1  Red Wine
# 243568                                         Pinot Noir        1  Red Wine
# 199020                                         Pinot Noir        1  Red Wine
# 145775                   The Wine Press Series Pinot Noir        1  Red Wine
# 300487                   The Wine Press Series Pinot Noir        1  Red Wine
# 157659                                         Pinot Noir        1  Red Wine
# 39438                                          Pinot Noir        1  Red Wine
#
#                      wine_region                     winery    winery_region  \
# 2445       Santa Lucia Highlands     Windstream - Windbreak    Central Coast
# 172429     Santa Lucia Highlands     Windstream - Windbreak    Central Coast
# 59214      Santa Lucia Highlands     Windstream - Windbreak    Central Coast
# 69060               Los Carneros                 Wine Spots      Napa Valley
# 327087              Sonoma Coast                 Wine Spots      Napa Valley
# 118387                 Glenrowan  Wine X Sam - Sam Plunkett         Victoria
# 98728         Strathbogie Ranges  Wine X Sam - Sam Plunkett         Victoria
# 246457            Central Valley         Winemaker's Choice   Côtes-du-Rhône
# 264453   South Eastern Australia         Winemaker's Choice   Côtes-du-Rhône
# 242240                   Mendoza         Winemaker's Choice   Côtes-du-Rhône
# 311733            Central Valley         Winemaker's Choice   Côtes-du-Rhône
# 9999            Mendocino County            Wines That Rock      North Coast
# 149109               North Coast            Wines That Rock      North Coast
# 224677                California                Winking Owl       California
# 245179                California                Winking Owl       California
# 93333                   Oakville                   Witchery       St. Helena
# 172113  Spring Mountain District                   Witchery       St. Helena
# 152801           Limestone Coast                Wm Morrison   Southern Rhône
# 144303   South Eastern Australia                Wm Morrison   Southern Rhône
# 285619                 Swartland                Wm Morrison   Southern Rhône
# 296024                 Somontano                Wm Morrison   Southern Rhône
# 313416             Central Otago                Wm Morrison   Southern Rhône
# 138590         Casablanca Valley                Wm Morrison   Southern Rhône
# 134927              Stellenbosch                Wm Morrison   Southern Rhône
# 269515           Limestone Coast                Wm Morrison   Southern Rhône
# 108435                   Barossa                Wm Morrison   Southern Rhône
# 239757                     Douro                Wm Morrison   Southern Rhône
# 288068                   Priorat                Wm Morrison   Southern Rhône
# 244529                Coonawarra                 Wolf Blass          Barossa
# 240670                Coonawarra                 Wolf Blass          Barossa
# 169404            Adelaide Hills                 Wolf Blass          Barossa
# 165851           Limestone Coast                 Wolf Blass          Barossa
# 165867              McLaren Vale                 Wolf Blass          Barossa
# 339877                   Barossa                 Wolf Blass          Barossa
# 57836                 California              Wolfgang Puck       California
# 94430                Napa Valley              Wolfgang Puck       California
# 172785      Santa Cruz Mountains                 Woodenhead    Sonoma County
# 54512       Russian River Valley                 Woodenhead    Sonoma County
# 32126            Humboldt County                 Woodenhead    Sonoma County
# 241818           Mendocino Ridge                 Woodenhead    Sonoma County
# 248411                Rutherford                    Xanthos      Napa Valley
# 12400                   Oakville                    Xanthos      Napa Valley
# 223193            Bennett Valley                    Xanthos      Napa Valley
# 21787       Russian River Valley                    Xanthos      Napa Valley
# 243568      Russian River Valley                      Ziata      Napa Valley
# 199020              Los Carneros                      Ziata      Napa Valley
# 145775              Sonoma Coast               Zilzie Wines   Murray Darling
# 300487            Murray Darling               Zilzie Wines   Murray Darling
# 157659             delle Venezie                     l'Arca  Maremma Toscana
# 39438            Terre Siciliane                     l'Arca  Maremma Toscana
#
#               country  ratings_count  ratings_average  alcohol   acidity  \
# 2445    United States             11              3.6     14.5  3.500000
# 172429  United States             71              3.9      0.0  3.797949
# 59214   United States             71              3.3      0.0  3.711818
# 69060   United States            406              3.9      0.0  3.543049
# 327087  United States             60              4.2      0.0  3.310513
# 118387      Australia            510              3.7      0.0  3.077784
# 98728       Australia             51              3.6      0.0  2.822056
# 246457         France             92              2.8      0.0  3.000000
# 264453         France             44              3.3      0.0  3.303834
# 242240         France            182              3.4      0.0  2.500000
# 311733         France             35              3.6      0.0  2.672174
# 9999    United States             97              3.4     13.5  3.000000
# 149109  United States            240              3.4      0.0  3.689474
# 224677  United States           1473              3.2      0.0  2.745903
# 245179  United States             58              3.5      0.0  3.078334
# 93333   United States            141              4.4     14.8  3.500000
# 172113  United States             15              4.4     14.6  3.264717
# 152801         France            106              3.4      0.0  3.528788
# 144303         France             39              3.3      0.0  3.479131
# 285619         France             41              3.6      0.0  4.000000
# 296024         France             50              3.6      0.0  3.523939
# 313416         France             21              3.3      0.0  3.902333
# 138590         France            321              3.3      0.0  3.209137
# 134927         France            108              3.3      0.0  3.528649
# 269515         France            152              3.4      0.0  3.187829
# 108435         France             59              3.4      0.0  3.091481
# 239757         France            306              3.6      0.0  2.887129
# 288068         France            282              3.6      0.0  3.552833
# 244529      Australia            157              3.6      0.0  3.415586
# 240670      Australia             14              4.0      0.0  3.436000
# 169404      Australia             17              3.6     13.5  3.165714
# 165851      Australia            272              3.1      0.0  3.437520
# 165867      Australia           4267              4.0     14.5  3.025433
# 339877      Australia             33              3.8      0.0  2.885738
# 57836   United States             62              3.4      0.0  2.804878
# 94430   United States             69              4.2      0.0  3.549091
# 172785  United States             21              3.9      0.0  3.543750
# 54512   United States            264              4.2     13.5  3.451992
# 32126   United States             48              4.2     13.7  3.745325
# 241818  United States             18              4.0      0.0  3.307792
# 248411  United States            744              4.0     14.5  3.191783
# 12400   United States            125              4.0      0.0  3.125823
# 223193  United States             44              4.0     15.0  3.071228
# 21787   United States             10              4.3      0.0  3.000000
# 243568  United States             46              4.0     14.1  3.470476
# 199020  United States             53              4.2     14.1  3.513235
# 145775      Australia             29              3.3      0.0  3.500000
# 300487      Australia             39              3.1      0.0  3.195309
# 157659          Italy            175              3.7      0.0  3.521200
# 39438           Italy             37              3.8     13.0  2.650571
#
#         fizziness  intensity  sweetness    tannin  \
# 2445          NaN   3.000000   1.000000  2.000000
# 172429        NaN   3.079829   1.000000  2.672992
# 59214         NaN   3.318283   1.667273  2.134646
# 69060         NaN   3.099103   1.696861  2.377489
# 327087        NaN   3.250257   1.594530  2.010085
# 118387        NaN   4.761821   2.171410  3.034886
# 98728         NaN   4.687850   2.254299  2.716449
# 246457        NaN   4.500000   1.000000  3.500000
# 264453        NaN   4.906833   2.035667  3.384833
# 242240        NaN   3.985766   1.793358  1.897518
# 311733        NaN   3.979565   2.287826  2.005217
# 9999          NaN   4.670588   1.441176  3.427647
# 149109        NaN   4.585614   1.751345  3.243158
# 224677        NaN   4.388092   1.738725  3.574568
# 245179        NaN   4.505714   1.094286  3.842857
# 93333         NaN   4.931062   1.284581  3.713184
# 172113        NaN   5.000000   1.490755  3.715472
# 152801        NaN   4.038939   1.106061  3.521212
# 144303        NaN   3.796522   1.533478  3.861304
# 285619        NaN   4.371795   1.193846  3.909231
# 296024        NaN   5.000000   2.372525  3.696768
# 313416        NaN   1.969333   1.038333  1.966000
# 138590        NaN   2.906045   1.490091  1.117000
# 134927        NaN   4.423243   1.518198  2.981351
# 269515        NaN   4.630395   1.826908  3.360724
# 108435        NaN   5.000000   1.621605  3.176296
# 239757        NaN   4.915313   1.335347  3.493993
# 288068        NaN   4.844572   1.472024  3.333262
# 244529        NaN   4.086641   1.474531  3.936875
# 240670        NaN   3.845334   1.288000  3.508000
# 169404        NaN   3.064286   1.533572  1.467857
# 165851        NaN   2.828320   1.392520  2.052120
# 165867        NaN   4.763183   2.121417  3.039120
# 339877        NaN   4.502623   1.869672  3.452951
# 57836         NaN   5.000000   1.095122  3.472439
# 94430         NaN   5.000000   1.598182  3.559818
# 172785        NaN   3.277778   1.556111  1.976528
# 54512         NaN   2.794780   1.494570  2.058407
# 32126         NaN   3.000000   1.448052  2.038441
# 241818        NaN   3.127273   1.124675  1.935714
# 248411        NaN   4.806804   1.655423  3.268351
# 12400         NaN   4.769358   1.698394  3.404137
# 223193        NaN   4.570878   1.298070  3.903333
# 21787         NaN   4.267586   1.724138  3.357241
# 243568        NaN   2.832976   1.139643  2.003869
# 199020        NaN   3.046324   1.122059  2.002985
# 145775        NaN   3.000000   1.000000  2.000000
# 300487        NaN   2.864321   1.215309  1.600494
# 157659        NaN   2.548720   1.137760  1.922720
# 39438         NaN   4.625429   1.921143  2.594571
#
#                                                       url
# 2445    https://www.vivino.com/GB/en/windstream-windbr...
# 172429  https://www.vivino.com/GB/en/windstream-windbr...
# 59214   https://www.vivino.com/GB/en/windstream-windbr...
# 69060   https://www.vivino.com/GB/en/wine-spots-pinot-...
# 327087  https://www.vivino.com/GB/en/wine-spots-pinot-...
# 118387  https://www.vivino.com/GB/en/wine-x-sam-sam-pl...
# 98728   https://www.vivino.com/GB/en/wine-x-sam-sam-pl...
# 246457  https://www.vivino.com/GB/en/winemaker-s-choic...
# 264453  https://www.vivino.com/GB/en/winemaker-s-choic...
# 242240  https://www.vivino.com/GB/en/winemaker-s-choic...
# 311733  https://www.vivino.com/GB/en/winemaker-s-choic...
# 9999    https://www.vivino.com/GB/en/us-wines-rock-pin...
# 149109  https://www.vivino.com/GB/en/us-wines-rock-pin...
# 224677  https://www.vivino.com/GB/en/winking-owl-shira...
# 245179  https://www.vivino.com/GB/en/winking-owl-shira...
# 93333   https://www.vivino.com/GB/en/witchery-58840-ca...
# 172113  https://www.vivino.com/GB/en/witchery-58840-ca...
# 152801  https://www.vivino.com/GB/en/wm-morrison-caber...
# 144303  https://www.vivino.com/GB/en/wm-morrison-caber...
# 285619  https://www.vivino.com/GB/en/wm-morrison-caber...
# 296024  https://www.vivino.com/GB/en/wm-morrison-caber...
# 313416  https://www.vivino.com/GB/en/wm-morrison-pinot...
# 138590  https://www.vivino.com/GB/en/wm-morrison-pinot...
# 134927  https://www.vivino.com/GB/en/wm-morrison-shira...
# 269515  https://www.vivino.com/GB/en/wm-morrison-shira...
# 108435  https://www.vivino.com/GB/en/wm-morrison-shira...
# 239757  https://www.vivino.com/GB/en/wm-morrison-tinto...
# 288068  https://www.vivino.com/GB/en/wm-morrison-prior...
# 244529  https://www.vivino.com/GB/en/wolf-blass-blass-...
# 240670  https://www.vivino.com/GB/en/wolf-blass-blass-...
# 169404  https://www.vivino.com/GB/en/wolf-blass-gold-l...
# 165851  https://www.vivino.com/GB/en/wolf-blass-gold-l...
# 165867  https://www.vivino.com/GB/en/wolf-blass-grey-l...
# 339877  https://www.vivino.com/GB/en/wolf-blass-grey-l...
# 57836   https://www.vivino.com/GB/en/wolfgang-puck-cab...
# 94430   https://www.vivino.com/GB/en/wolfgang-puck-cab...
# 172785  https://www.vivino.com/GB/en/us-woodenhead-pin...
# 54512   https://www.vivino.com/GB/en/us-woodenhead-pin...
# 32126   https://www.vivino.com/GB/en/us-woodenhead-pin...
# 241818  https://www.vivino.com/GB/en/us-woodenhead-pin...
# 248411  https://www.vivino.com/GB/en/xanthos-cabernet-...
# 12400   https://www.vivino.com/GB/en/xanthos-cabernet-...
# 223193  https://www.vivino.com/GB/en/xanthos-syrah/w/3...
# 21787   https://www.vivino.com/GB/en/xanthos-syrah-rus...
# 243568  https://www.vivino.com/GB/en/ziata-pinot-noir-...
# 199020  https://www.vivino.com/GB/en/ziata-pinot-noir/...
# 145775  https://www.vivino.com/GB/en/zilzie-wines-the-...
# 300487  https://www.vivino.com/GB/en/zilzie-wines-the-...
# 157659  https://www.vivino.com/GB/en/l-arca-pinot-noir...
# 39438   https://www.vivino.com/GB/en/l-arca-pinot-noir...

# %%
# Imprimindo para verificação as URLs de alguns dos vinhos duplicados pelo atributo full_name
url_ids = [237297, 247021, 69060, 327087, 224677, 245179, 172785, 54512, 223193, 21787]

with pd.option_context('display.max_colwidth', 150):
    for url in url_ids:
        print('{}\n{}'.format(vivino_wines.loc[url, ['full_name']], vivino_wines.loc[url, ['url']]))
# Out:
# full_name    18401 Cellars Proprietary Red
# Name: 237297, dtype: object
# url    https://www.vivino.com/GB/en/onehundredeightyfour-zero-one-cellars-proprietary-red-us-walla-walla-valley/w/3803882
# Name: 237297, dtype: object
# full_name    18401 Cellars Proprietary Red
# Name: 247021, dtype: object
# url    https://www.vivino.com/GB/en/onehundredeightyfour-zero-one-cellars-proprietary-red/w/4187752
# Name: 247021, dtype: object
# full_name    Wine Spots Pinot Noir
# Name: 69060, dtype: object
# url    https://www.vivino.com/GB/en/wine-spots-pinot-noir-los-carneros/w/1487150
# Name: 69060, dtype: object
# full_name    Wine Spots Pinot Noir
# Name: 327087, dtype: object
# url    https://www.vivino.com/GB/en/wine-spots-pinot-noir/w/6421614
# Name: 327087, dtype: object
# full_name    Winking Owl Shiraz
# Name: 224677, dtype: object
# url    https://www.vivino.com/GB/en/winking-owl-shiraz/w/1152892
# Name: 224677, dtype: object
# full_name    Winking Owl Shiraz
# Name: 245179, dtype: object
# url    https://www.vivino.com/GB/en/winking-owl-shiraz-california/w/4112346
# Name: 245179, dtype: object
# full_name    Woodenhead Pinot Noir
# Name: 172785, dtype: object
# url    https://www.vivino.com/GB/en/us-woodenhead-pinot-noir-santa-cruz-mountains/w/2322210
# Name: 172785, dtype: object
# full_name    Woodenhead Pinot Noir
# Name: 54512, dtype: object
# url    https://www.vivino.com/GB/en/us-woodenhead-pinot-noir-russian-river-valley/w/1371075
# Name: 54512, dtype: object
# full_name    Xanthos Syrah
# Name: 223193, dtype: object
# url    https://www.vivino.com/GB/en/xanthos-syrah/w/3308946
# Name: 223193, dtype: object
# full_name    Xanthos Syrah
# Name: 21787, dtype: object
# url    https://www.vivino.com/GB/en/xanthos-syrah-russian-river-valley/w/7509047
# Name: 21787, dtype: object

# %%
vivino_wines[vivino_wines.duplicated(subset=['full_name'],keep=False)]\
            .sort_values(by=['full_name', 'ratings_count'],ascending=[True, False])
# Out:
#              id                                      full_name  \
# 247021  4187752                  18401 Cellars Proprietary Red
# 237297  3803882                  18401 Cellars Proprietary Red
# 260788  1181992                            3 Stones Pinot Noir
# 124566    83508                            3 Stones Pinot Noir
# 78982   1562698                      8th Generation Pinot Noir
# ...         ...                                            ...
# 243568  4039842                               Ziata Pinot Noir
# 300487  5711914  Zilzie Wines The Wine Press Series Pinot Noir
# 145775  2046503  Zilzie Wines The Wine Press Series Pinot Noir
# 157659  2203665                              l'Arca Pinot Noir
# 39438   8549704                              l'Arca Pinot Noir
#
#                                     name  type_id      type  \
# 247021                   Proprietary Red        1  Red Wine
# 237297                   Proprietary Red        1  Red Wine
# 260788                        Pinot Noir        1  Red Wine
# 124566                        Pinot Noir        1  Red Wine
# 78982                         Pinot Noir        1  Red Wine
# ...                                  ...      ...       ...
# 243568                        Pinot Noir        1  Red Wine
# 300487  The Wine Press Series Pinot Noir        1  Red Wine
# 145775  The Wine Press Series Pinot Noir        1  Red Wine
# 157659                        Pinot Noir        1  Red Wine
# 39438                         Pinot Noir        1  Red Wine
#
#                  wine_region          winery    winery_region        country  \
# 247021    Walla Walla Valley   18401 Cellars           Oregon  United States
# 237297    Walla Walla Valley   18401 Cellars           Oregon  United States
# 260788        Central Valley        3 Stones      Marlborough    New Zealand
# 124566           Marlborough        3 Stones      Marlborough    New Zealand
# 78982        Okanagan Valley  8th Generation  Okanagan Valley         Canada
# ...                      ...             ...              ...            ...
# 243568  Russian River Valley           Ziata      Napa Valley  United States
# 300487        Murray Darling    Zilzie Wines   Murray Darling      Australia
# 145775          Sonoma Coast    Zilzie Wines   Murray Darling      Australia
# 157659         delle Venezie          l'Arca  Maremma Toscana          Italy
# 39438        Terre Siciliane          l'Arca  Maremma Toscana          Italy
#
#         ratings_count  ratings_average  alcohol   acidity  fizziness  \
# 247021             68              4.3      0.0  3.677327        NaN
# 237297             42              4.2      0.0  4.072941        NaN
# 260788            222              3.4     14.0  3.215273        NaN
# 124566             32              3.7     13.0  3.262821        NaN
# 78982             118              3.8     13.6  3.980962        NaN
# ...               ...              ...      ...       ...        ...
# 243568             46              4.0     14.1  3.470476        NaN
# 300487             39              3.1      0.0  3.195309        NaN
# 145775             29              3.3      0.0  3.500000        NaN
# 157659            175              3.7      0.0  3.521200        NaN
# 39438              37              3.8     13.0  2.650571        NaN
#
#         intensity  sweetness    tannin  \
# 247021   3.655050   1.458713  3.206634
# 237297   3.839411   1.578235  3.470000
# 260788   3.026637   1.542000  1.392818
# 124566   2.861538   1.314744  1.860128
# 78982    2.439251   1.000000  2.419626
# ...           ...        ...       ...
# 243568   2.832976   1.139643  2.003869
# 300487   2.864321   1.215309  1.600494
# 145775   3.000000   1.000000  2.000000
# 157659   2.548720   1.137760  1.922720
# 39438    4.625429   1.921143  2.594571
#
#                                                       url
# 247021  https://www.vivino.com/GB/en/onehundredeightyf...
# 237297  https://www.vivino.com/GB/en/onehundredeightyf...
# 260788  https://www.vivino.com/GB/en/three-stones-pino...
# 124566  https://www.vivino.com/GB/en/three-stones-pino...
# 78982   https://www.vivino.com/GB/en/eight-th-generati...
# ...                                                   ...
# 243568  https://www.vivino.com/GB/en/ziata-pinot-noir-...
# 300487  https://www.vivino.com/GB/en/zilzie-wines-the-...
# 145775  https://www.vivino.com/GB/en/zilzie-wines-the-...
# 157659  https://www.vivino.com/GB/en/l-arca-pinot-noir...
# 39438   https://www.vivino.com/GB/en/l-arca-pinot-noir...
#
# [2551 rows x 18 columns]

# %%
vivino_wines = vivino_wines.sort_values(by=['full_name', 'ratings_count'], ascending=[True, False])\
            .drop_duplicates(subset=['full_name'], keep='first')

# %% [markdown]
# ### Tratamento de dados omissos
# - Foram encontrados valores omissos em 4 colunas e dados os seguintes tratamentos:
#  - **Fizziness**: a coluna em questão indica o nível de presença de gás (efervescência) do vinho espumante em uma escala de 1 (delicado) a 5 (com gás). Tal medida é própria para espumantes e isso explica o porquê da ausência de 99.99% do preenchimento do campo após a filtragem do dataset para vinhos tintos. A coluna foi removida do dataset.
#  - **Tannin**: Os 41 registros omissos (0,02%) foram preenchidos com a média.
#  - **Sweetness**: Os 8 registros omissos (0.004%) foram preenchidos com a média.
#  - **Name**: Apenas 1 registro omisso. Ao analisar a imagem do rótulo do vinho no site do Vivino percebeu-se que o nome do vinho é 'NA' e estava sendo interpretado como registro nulo. O registro foi corrigido para o nome correto.

# %%
values_missing(vivino_wines)
# Out:
#            percent_missing  rows_missing
# fizziness        99.995660        207387
# tannin            0.019769            41
# sweetness         0.003857             8
# name              0.000482             1

# %%
# Remoção da coluna fizziness - própria de espumantes
vivino_wines = vivino_wines.drop('fizziness', axis=1)

# %%
# Tannin: registros omissos preenchidos com a média
vivino_wines['tannin'] = vivino_wines['tannin'].fillna(vivino_wines['tannin'].mean())
# Sweetness: registros omissos preenchidos com a média
vivino_wines['sweetness'] = vivino_wines['sweetness'].fillna(vivino_wines['sweetness'].mean())

# %%
# Name
vivino_wines[vivino_wines['name'].isnull()]
# Out:
#              id                full_name name  type_id      type wine_region  \
# 220170  3155521  Monte da Ravasqueira NA  NaN        1  Red Wine    Alentejo
#
#                       winery winery_region   country  ratings_count  \
# 220170  Monte da Ravasqueira      Alentejo  Portugal            113
#
#         ratings_average  alcohol  acidity  intensity  sweetness  tannin  \
# 220170              3.7     13.5   2.9057     4.0772     1.7391  2.6465
#
#                                                       url
# 220170  https://www.vivino.com/GB/en/monte-da-ravasque...

# %%
# URL do vinho com nome ausente
with pd.option_context('display.max_colwidth', 150):
    print(vivino_wines[vivino_wines['name'].isnull()].url)
# Out:
# 220170    https://www.vivino.com/GB/en/monte-da-ravasqueira-na/w/3155521
# Name: url, dtype: object

# %%
# Corrigindo nome "ausente"
vivino_wines.loc[220170, 'name'] = 'Monte da Ravasqueira NA'
vivino_wines.loc[[220170]]
# Out:
#              id                full_name                     name  type_id  \
# 220170  3155521  Monte da Ravasqueira NA  Monte da Ravasqueira NA        1
#
#             type wine_region                winery winery_region   country  \
# 220170  Red Wine    Alentejo  Monte da Ravasqueira      Alentejo  Portugal
#
#         ratings_count  ratings_average  alcohol  acidity  intensity  \
# 220170            113              3.7     13.5   2.9057     4.0772
#
#         sweetness  tannin                                                url
# 220170     1.7391  2.6465  https://www.vivino.com/GB/en/monte-da-ravasque...

# %%
values_missing(vivino_wines)
# Out:
# Empty DataFrame
# Columns: [percent_missing, rows_missing]
# Index: []

# %% [markdown]
# ### Remoção de colunas
# - As colunas **type_id**, **type** e **url** foram removidas do dataset. As colunas de tipo foram usadas para filtrar o dataset para somente vinhos tintos, portanto pode ser removida pois os valores das colunas possuem sempreo mesmo valor. A coluna url foi gravada para facilitar identificar possíveis erros oriundos da coleta e não terá mais uso de agora em diante.

# %%
vivino_wines = vivino_wines.drop(['type_id', 'type', 'url'], axis=1)

# %%
## Dos 210.432 registros de vinhos tintos inicialmente (após a filtragem), após a tratamento dos registros duplicados 
## e omissos têm-se 207.396 registros.
vivino_wines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 207396 entries, 40773 to 172196
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               207396 non-null  int64
#  1   full_name        207396 non-null  object
#  2   name             207396 non-null  object
#  3   wine_region      207396 non-null  object
#  4   winery           207396 non-null  object
#  5   winery_region    207396 non-null  object
#  6   country          207396 non-null  object
#  7   ratings_count    207396 non-null  int64
#  8   ratings_average  207396 non-null  float64
#  9   alcohol          207396 non-null  float64
#  10  acidity          207396 non-null  float64
#  11  intensity        207396 non-null  float64
#  12  sweetness        207396 non-null  float64
#  13  tannin           207396 non-null  float64
# dtypes: float64(6), int64(2), object(6)
# memory usage: 33.7+ MB

# %% [markdown]
# ## Dataset: Vivino Vintages

# %%
# Dataset com os dados de safras/ano de engarrafamento
vivino_vintages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1290886 entries, 0 to 1290885
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   year                     1290886 non-null  int64
#  1   id                       1290886 non-null  int64
#  2   wine_id                  1290886 non-null  int64
#  3   vintage_ratings_count    1290886 non-null  int64
#  4   vintage_ratings_average  1290886 non-null  float64
# dtypes: float64(1), int64(4)
# memory usage: 49.2 MB

# %% [markdown]
# ### Filtragem
# - nenhuma filtragem foi necessária, pois após a unificação de todos os datasets do Vivino, a filtragem feita no dataset Vivino Wines garantirá que apenas vinhos tintos estejam no dataset final.

# %% [markdown]
# ### Tratamento de dados duplicados
# - Foram encontrados e removidos 9418 registros inteiramente duplicados. Reduzind os 1.290.886 registros iniciais para 1.281.468 registros.

# %%
# Remoção de registros inteiramente duplicados
print('vivino_vintages: Foram encontrados {} registros inteiramente duplicados'.format(vivino_vintages.duplicated().sum()))

vivino_vintages = vivino_vintages.drop_duplicates()
print('Total de registros após a remoção dos registro duplicados: {}'.format(vivino_vintages.shape[0]))
# Out:
# vivino_vintages: Foram encontrados 9418 registros inteiramente duplicados
# Total de registros após a remoção dos registro duplicados: 1281468

# %%
print('vivino_vintages: Foram encontrados {} registros duplicados pelo ID'\
      .format(vivino_vintages.duplicated(subset=['id']).sum()))
# Out:
# vivino_vintages: Foram encontrados 0 registros duplicados pelo ID

# %%
print('vivino_vintages: Foram encontrados {} registros duplicados pelo ID do vinho e ano de engarrafamento/safra'\
      .format(vivino_vintages.duplicated(subset=['wine_id', 'year']).sum()))
# Out:
# vivino_vintages: Foram encontrados 0 registros duplicados pelo ID do vinho e ano de engarrafamento/safra

# %% [markdown]
# ### Tratamento de dados omissos
# - Não foram encontrados dados omissos em todo o dataset.

# %%
values_missing(vivino_vintages)
# Out:
# Empty DataFrame
# Columns: [percent_missing, rows_missing]
# Index: []

# %% [markdown]
# ## Unificação dos datasets da Vivino
# - Os 207.396 registros de vinhos tintos presentes no dataset Vivino Wines foram enriquecidos com as informações de safras específicas/ano engarramento de VIvino Vintages, o que levou o dataset a 874.676 registros. Importante notar que agora a unicidade do vinho deixa de ser apenas pelo **full_name**, sendo que a partir de agora deve levar em conta o atributo **year**. Isso permitirá na próxima a junção com o dataset da Wine Enthusiast Magazine.

# %%
# Merge do dataset Vivino Wines com Vivino Vintages. A coluna id do segundo dataset foi renomeada para vintage_id,
# pois já existe outra coluna id no primeiro dataset. Após o merge, a coluna wine_id usada para o merge foi descartada.
vivino_red = pd.merge(vivino_wines, vivino_vintages.rename({'id': 'vintage_id'}, axis=1), left_on='id', right_on='wine_id')\
            .drop('wine_id', axis=1)

# %%
vivino_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 874676 entries, 0 to 874675
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       874676 non-null  int64
#  1   full_name                874676 non-null  object
#  2   name                     874676 non-null  object
#  3   wine_region              874676 non-null  object
#  4   winery                   874676 non-null  object
#  5   winery_region            874676 non-null  object
#  6   country                  874676 non-null  object
#  7   ratings_count            874676 non-null  int64
#  8   ratings_average          874676 non-null  float64
#  9   alcohol                  874676 non-null  float64
#  10  acidity                  874676 non-null  float64
#  11  intensity                874676 non-null  float64
#  12  sweetness                874676 non-null  float64
#  13  tannin                   874676 non-null  float64
#  14  year                     874676 non-null  int64
#  15  vintage_id               874676 non-null  int64
#  16  vintage_ratings_count    874676 non-null  int64
#  17  vintage_ratings_average  874676 non-null  float64
# dtypes: float64(7), int64(5), object(6)
# memory usage: 126.8+ MB

# %% [markdown]
# ### Exportação do dataset

# %%
# Exporta o dataset para arquivo csv após o tratamento dado até o momento
vivino_red.to_csv('datasets/vivino_red.csv', index=False, header=True)
