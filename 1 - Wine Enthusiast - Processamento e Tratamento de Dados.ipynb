# %% [markdown]
# ### Etapas iniciais: importação de pacotes, definição de funções, carregamento de dados

# %%
import pandas as pd

# %%
def values_missing(df, only_missing=True):
    '''Calcula e retorna o percentual e o número de registros nulos no dataframe df'''
    missing = pd.concat({'percent_missing': 100* df.isnull().sum() / len(df),
                         'rows_missing': df.isnull().sum()}, axis=1)
    if only_missing:
        missing = missing[missing.percent_missing > 0]
    return missing.sort_values(by='percent_missing', ascending=False)

# %%
winemag = pd.read_csv('datasets/winemag_reviews.csv')
winemag.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149693 entries, 0 to 149692
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Title        149693 non-null  object
#  1   Description  149608 non-null  object
#  2   Taster       144183 non-null  object
#  3   Rating       149693 non-null  int64
#  4   Price        141564 non-null  object
#  5   Designation  109320 non-null  object
#  6   Variety      149692 non-null  object
#  7   Appellation  149693 non-null  object
#  8   Winery       149693 non-null  object
#  9   Alcohol      143313 non-null  object
#  10  Bottle Size  149693 non-null  object
#  11  Category     149693 non-null  object
#  12  URL          149693 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 14.8+ MB

# %% [markdown]
# ### Filtragem
# - O dataset originalmente continha 149.693 registros, os quais cobriam diversos tipos/categorias, como vinhos brancos, espumantes e tintos. Como o trabalho restringe-se a vinhos tintos, nessa etapa foram filtrados apenas os vinhos dessa categoria resultando em  87.574 registros.<br>

# %%
winemag = winemag[ winemag.Category == 'Red' ]

# %%
winemag.head()
# Out:
#                                                Title  \
# 0  Cantina Tollo 2015 Cagiòlo Riserva  (Montepulc...
# 1             Amorotti 2016  Montepulciano d'Abruzzo
# 2    Francesco Cirelli 2018  Montepulciano d'Abruzzo
# 3  Terra d'Aligi 2016 Tatone  (Montepulciano d'Ab...
# 4  Talamonti 2017 Tre Saggi  (Montepulciano d'Abr...
#
#                                          Description              Taster  \
# 0  Densely packed aromas of brandy-soaked plums a...  Alexander Peartree
# 1  Dense aromas of black plum and blackberry are ...  Alexander Peartree
# 2  Freshly pressed blackberries, cherries and cra...  Alexander Peartree
# 3  Dense aromas of brandy-dipped cherries and bla...  Alexander Peartree
# 4  This lavish red is all about rich fruit and wa...  Alexander Peartree
#
#    Rating     Price      Designation                     Variety  \
# 0      92  R$ 35,00  Cagiòlo Riserva  Montepulciano, Italian Red
# 1      93  R$ 44,00              NaN  Montepulciano, Italian Red
# 2      93  R$ 22,00              NaN  Montepulciano, Italian Red
# 3      91  R$ 17,00           Tatone  Montepulciano, Italian Red
# 4      89  R$ 19,00        Tre Saggi  Montepulciano, Italian Red
#
#                                      Appellation             Winery Alcohol  \
# 0  Montepulciano d'Abruzzo, Central Italy, Italy      Cantina Tollo  14,50%
# 1  Montepulciano d'Abruzzo, Central Italy, Italy           Amorotti  14,00%
# 2  Montepulciano d'Abruzzo, Central Italy, Italy  Francesco Cirelli  13,00%
# 3  Montepulciano d'Abruzzo, Central Italy, Italy      Terra d'Aligi  14,00%
# 4  Montepulciano d'Abruzzo, Central Italy, Italy          Talamonti  13,50%
#
#   Bottle Size Category                                                URL
# 0      750 ml      Red  https://www.winemag.com/buying-guide/cantina-t...
# 1      750 ml      Red  https://www.winemag.com/buying-guide/amorotti-...
# 2      750 ml      Red  https://www.winemag.com/buying-guide/francesco...
# 3      750 ml      Red  https://www.winemag.com/buying-guide/terra-dal...
# 4      750 ml      Red  https://www.winemag.com/buying-guide/talamonti...

# %% [markdown]
# ### Tratamento de dados duplicados
#  - Nenhum registro inteiramente duplicado foi encontrado;
#  - Quando analisado pela coluna **Title** foram obtidos 314 registros duplicados (0.38% dos registros); desses 303 estavam duplicados também pela coluna **Taster**, indicando qu nos outros 9 casos o vinho foi objetivo foi objeto de análise por mais de um degustador; 85 dos registros duplicados possuiam também o valor do **Rating** distinto.
#  - Analisando os registros duplicados no dataframe e acessando as URLs descritas no campo **url** é possível perceber que muitos dos registros duplicados devem-se a novas análises feitas sobre o vinho, seja pelo mesmo degustador ou não; na maioria dos casos a nota atribuída ao vinho permaneceu a mesma.
#  - Foi optado por manter no dataset apenas o registro correspondente a análise mais recente publicada sobre o vinho, por entender que a análise mais recente é a versão mais definitiva do parecer sobre o vinho; reduzindo o número de registros para 82.260.

# %%
# Nenhum registro inteiramente duplicado
winemag[ winemag.duplicated() ]
# Out:
# Empty DataFrame
# Columns: [Title, Description, Taster, Rating, Price, Designation, Variety, Appellation, Winery, Alcohol, Bottle Size, Category, URL]
# Index: []

# %%
# 314 reviews de vinho duplicados quando 
winemag.duplicated(subset=['Title']).sum()
# Out:
# 314

# %%
# Exibindo parte do dataset duplicado (em conjunto com os "originais") para melhor compreender a duplicidade
winemag[ winemag.duplicated(subset=['Title'], keep=False) ].sort_values(by='Title').head(50)
# Out:
#                                                     Title  \
# 31405           Ada Nada 2012 Rombone Elisa  (Barbaresco)
# 53182           Ada Nada 2012 Rombone Elisa  (Barbaresco)
# 131487  Adega Cooperativa do Cartaxo 2015 Bridão Colhe...
# 140822  Adega Cooperativa do Cartaxo 2015 Bridão Colhe...
# 32483   Adriano Marco & Vittorio 2013 Basarin  (Barbar...
# 109763  Adriano Marco & Vittorio 2013 Basarin  (Barbar...
# 81734   Albert Bichot 2018 Domaine de Rochegrès  (Moul...
# 82204   Albert Bichot 2018 Domaine de Rochegrès  (Moul...
# 6675    Amador Cellars 2016 Estate Zinfandel (Shenando...
# 81357   Amador Cellars 2016 Estate Zinfandel (Shenando...
# 65518               Anemoi 2012 Boreas Red (Grand Valley)
# 53115               Anemoi 2012 Boreas Red (Grand Valley)
# 39688   Angove 2012 The Medhyk Old Vine Shiraz (McLare...
# 41929   Angove 2012 The Medhyk Old Vine Shiraz (McLare...
# 119392                        Banfi 2014 Aska  (Bolgheri)
# 12845                         Banfi 2014 Aska  (Bolgheri)
# 5182    Barden 2017 Sanford & Benedict Vineyard Pinot ...
# 115876  Barden 2017 Sanford & Benedict Vineyard Pinot ...
# 5704                      Barefoot NV Malbec (California)
# 134423                    Barefoot NV Malbec (California)
# 137728                Barefoot NV Pinot Noir (California)
# 5703                  Barefoot NV Pinot Noir (California)
# 113674              Baron De Ley 2015 Varietales  (Rioja)
# 134798              Baron De Ley 2015 Varietales  (Rioja)
# 88750       Bel Vino 2016 Cabernet Sauvignon (California)
# 122073      Bel Vino 2016 Cabernet Sauvignon (California)
# 108149             Bellini 2014 Riserva  (Chianti Rufina)
# 135978             Bellini 2014 Riserva  (Chianti Rufina)
# 25842   Bianchi 2012 Signature Selection Cabernet Sauv...
# 42766   Bianchi 2012 Signature Selection Cabernet Sauv...
# 121925  Bodega de Edgar 2014 Laetitia Vineyard Tempran...
# 143784  Bodega de Edgar 2014 Laetitia Vineyard Tempran...
# 44482   Bodegas Ontañón 2005 Reserva Tempranillo-Graci...
# 54538   Bodegas Ontañón 2005 Reserva Tempranillo-Graci...
# 78896                  Boeckel 2017 K Pinot Noir (Alsace)
# 102517                 Boeckel 2017 K Pinot Noir (Alsace)
# 102526      Boeckel 2017 Oberpfoeller Pinot Noir (Alsace)
# 78888       Boeckel 2017 Oberpfoeller Pinot Noir (Alsace)
# 34854                     Boeger 2013 Barbera (El Dorado)
# 28974                     Boeger 2013 Barbera (El Dorado)
# 135911  Bonny Doon 2013 Le Cigare Volant Reserve Red (...
# 115716  Bonny Doon 2013 Le Cigare Volant Reserve Red (...
# 115723         Bonny Doon 2016 Grenache (Monterey County)
# 114241         Bonny Doon 2016 Grenache (Monterey County)
# 71237                     Brandini 2015 Meriame  (Barolo)
# 96424                     Brandini 2015 Meriame  (Barolo)
# 93109   Brecon Estate 2016 Cabernet Franc (Adelaida Di...
# 107515  Brecon Estate 2016 Cabernet Franc (Adelaida Di...
# 8794           Brecon Estate 2017 Red (Adelaida District)
# 74183          Brecon Estate 2017 Red (Adelaida District)
#
#                                               Description              Taster  \
# 31405   Fig, stewed prune, sun baked soil, camphor and...       Kerin O’Keefe
# 53182   This initially opens with funky aromas of barn...       Kerin O’Keefe
# 131487  Dense black fruits are the name of the game in...          Roger Voss
# 140822  This wine is soft and juicy, with ripe red fru...          Roger Voss
# 32483   This opens with aromas of mature black-skinned...       Kerin O’Keefe
# 109763  Menthol, rose, wild berry, aromatic herb and n...       Kerin O’Keefe
# 81734   Property of the Bichot family, this vineyard h...          Roger Voss
# 82204   This wine comes from a five-acre vineyard in t...          Roger Voss
# 6675    Very focused and delicious berry flavors give ...          Jim Gordon
# 81357   This is a monster of a wine, very ripe, extrem...          Jim Gordon
# 65518   Dark cherry and spicy currant aromas are lifte...  Alexander Peartree
# 53115   Cranberry and blackberry sauce aromas take on ...  Alexander Peartree
# 39688   The Angove family has made a real commitment t...      Joe Czerwinski
# 41929   A tip of the cap to the Angove family for turn...      Joe Czerwinski
# 119392  Made from Cabernet Sauvignon and Cabernet Fran...       Kerin O’Keefe
# 12845   A blend of Cabernet Sauvignon and Cabernet Fra...       Kerin O’Keefe
# 5182    Tense aromas of elderberry, crushed black rock...       Matt Kettmann
# 115876  This is the first time that Doug Margerum has ...       Matt Kettmann
# 5704    A grape jam aroma and flavor gives this wine a...          Jim Gordon
# 134423  This wine has a deep well of black fruit flavo...          Jim Gordon
# 137728  Light but flavorful and fresh, this wine has g...          Jim Gordon
# 5703    Smooth, supple and warmly fruity, this is a ch...          Jim Gordon
# 113674  Leathery, oaky berry aromas are baked and incl...   Michael Schachner
# 134798  Disparate aromas of chocolate, herbal black fr...   Michael Schachner
# 88750   This is a serviceable, simple wine that's medi...          Jim Gordon
# 122073  Freshly smashed red fruits meet with hints of ...       Matt Kettmann
# 108149  Aromas of dill, coconut and oak-driven spice l...       Kerin O’Keefe
# 135978  This has subdued baking spice and dark fruit a...       Kerin O’Keefe
# 25842   Dried black cherries, dried herbs, pencil shav...       Matt Kettmann
# 42766   Fresh-crushed red currant aromas mix with drie...       Matt Kettmann
# 121925  Bursting aromas of black raspberry, bright bla...       Matt Kettmann
# 143784  Impressively dark and dense in the glass, this...       Matt Kettmann
# 44482   Fruity but also showing saddle, game and vanil...   Michael Schachner
# 54538   Charred and oaky at first, the nose on this ag...   Michael Schachner
# 78896   A touch of reduction still hovers on the nose ...    Anne Krebiehl MW
# 102517  Fallen oak leaves and undergrowth are evoked o...    Anne Krebiehl MW
# 102526  The shy nose gives little away, but on the pal...    Anne Krebiehl MW
# 78888   Reductive funk still clouds the nose of this w...    Anne Krebiehl MW
# 34854   Smoky, earthy, black pepper aromas make this w...          Jim Gordon
# 28974   Well balanced and appetizing, this medium-bodi...          Jim Gordon
# 135911  This blend of 55% Grenache, 25% Syrah, 16% Mou...       Matt Kettmann
# 115716  This reserve blend of 55% Grenache, 25% Syrah,...       Matt Kettmann
# 115723  This blend of three properties from up and dow...       Matt Kettmann
# 114241  This blend of three vineyards, including one i...       Matt Kettmann
# 71237   Underbrush, sautéed herb and stewed prune arom...       Kerin O’Keefe
# 96424   Hailing from Serralunga, this firmly structure...       Kerin O’Keefe
# 93109   Strong aromas of red fruits and hibiscus conce...       Matt Kettmann
# 107515  Ripe red-cherry aromas meet with light mint an...       Matt Kettmann
# 8794    This unique blend of Syrah and Tannat starts w...       Matt Kettmann
# 74183   Tangy black-plum and white-pepper aromas conve...       Matt Kettmann
#
#         Rating      Price                   Designation  \
# 31405       92   R$ 47,00                 Rombone Elisa
# 53182       88        NaN                 Rombone Elisa
# 131487      86    R$ 8,00  Bridão Colheita Seleccionada
# 140822      87   R$ 12,00  Bridão Colheita Seleccionada
# 32483       90   R$ 40,00                       Basarin
# 109763      93   R$ 29,00                       Basarin
# 81734       93   R$ 33,00          Domaine de Rochegrès
# 82204       94   R$ 38,00          Domaine de Rochegrès
# 6675        92   R$ 45,00                        Estate
# 81357       87   R$ 28,00                        Estate
# 65518       87   R$ 40,00                        Boreas
# 53115       86   R$ 50,00                        Boreas
# 39688       92   R$ 95,00           The Medhyk Old Vine
# 41929       94   R$ 95,00           The Medhyk Old Vine
# 119392      89   R$ 33,00                          Aska
# 12845       89   R$ 34,00                          Aska
# 5182        93   R$ 82,00   Sanford & Benedict Vineyard
# 115876      95   R$ 80,00   Sanford & Benedict Vineyard
# 5704        86    R$ 7,00                           NaN
# 134423      86    R$ 7,00                           NaN
# 137728      87    R$ 7,00                           NaN
# 5703        90    R$ 7,00                           NaN
# 113674      87   R$ 12,00                    Varietales
# 134798      85   R$ 20,00                    Varietales
# 88750       82   R$ 50,00                           NaN
# 122073      88   R$ 30,00                           NaN
# 108149      86   R$ 20,00                       Riserva
# 135978      87   R$ 17,00                       Riserva
# 25842       86   R$ 21,00           Signature Selection
# 42766       87   R$ 19,00           Signature Selection
# 121925      91   R$ 48,00             Laetitia Vineyard
# 143784      93   R$ 38,00             Laetitia Vineyard
# 44482       93   R$ 25,00  Reserva Tempranillo-Graciano
# 54538       89   R$ 28,00  Reserva Tempranillo-Graciano
# 78896       92   R$ 40,00                             K
# 102517      90   R$ 40,00                             K
# 102526      90   R$ 30,00                  Oberpfoeller
# 78888       91   R$ 30,00                  Oberpfoeller
# 34854       90   R$ 18,00                           NaN
# 28974       90   R$ 16,00                           NaN
# 135911      92   R$ 60,00      Le Cigare Volant Reserve
# 115716      92   R$ 60,00      Le Cigare Volant Reserve
# 115723      89   R$ 32,00                           NaN
# 114241      88   R$ 32,00                           NaN
# 71237       92  R$ 140,00                       Meriame
# 96424       92  R$ 100,00                       Meriame
# 93109       90   R$ 62,00                           NaN
# 107515      90   R$ 58,00                           NaN
# 8794        88   R$ 58,00                           NaN
# 74183       89   R$ 60,00                           NaN
#
#                                                   Variety  \
# 31405                                            Nebbiolo
# 53182                                            Nebbiolo
# 131487                        Trincadeira, Portuguese Red
# 140822                        Trincadeira, Portuguese Red
# 32483                                            Nebbiolo
# 109763                                           Nebbiolo
# 81734                                               Gamay
# 82204                                               Gamay
# 6675                                            Zinfandel
# 81357                                           Zinfandel
# 65518                            Bordeaux-style Red Blend
# 53115                              Red Blends, Red Blends
# 39688                                              Shiraz
# 41929                                              Shiraz
# 119392                             Red Blends, Red Blends
# 12845                              Red Blends, Red Blends
# 5182                                           Pinot Noir
# 115876                                         Pinot Noir
# 5704                                               Malbec
# 134423                                             Malbec
# 137728                                         Pinot Noir
# 5703                                           Pinot Noir
# 113674                                        Tempranillo
# 134798                                 Garnacha, Grenache
# 88750                                  Cabernet Sauvignon
# 122073                                 Cabernet Sauvignon
# 108149                             Red Blends, Red Blends
# 135978                             Red Blends, Red Blends
# 25842                                  Cabernet Sauvignon
# 42766                                  Cabernet Sauvignon
# 121925                                        Tempranillo
# 143784                                        Tempranillo
# 44482                      Tempranillo Blend, Tempranillo
# 54538                      Tempranillo Blend, Tempranillo
# 78896                                          Pinot Noir
# 102517                                         Pinot Noir
# 102526                                         Pinot Noir
# 78888                                          Pinot Noir
# 34854                                             Barbera
# 28974                                             Barbera
# 135911                              Rhône-style Red Blend
# 115716                              Rhône-style Red Blend
# 115723                                           Grenache
# 114241                                           Grenache
# 71237                                            Nebbiolo
# 96424                                            Nebbiolo
# 93109                                      Cabernet Franc
# 107515                                     Cabernet Franc
# 8794                               Red Blends, Red Blends
# 74183   Cabernet Sauvignon-Petit Verdot, Bordeaux-styl...
#
#                                               Appellation  \
# 31405                         Barbaresco, Piedmont, Italy
# 53182                         Barbaresco, Piedmont, Italy
# 131487                                     Tejo, Portugal
# 140822                                     Tejo, Portugal
# 32483                         Barbaresco, Piedmont, Italy
# 109763                        Barbaresco, Piedmont, Italy
# 81734                   Moulin-à-Vent, Beaujolais, France
# 82204                   Moulin-à-Vent, Beaujolais, France
# 6675    Shenandoah Valley (CA), Sierra Foothills, Cali...
# 81357   Shenandoah Valley (CA), Sierra Foothills, Cali...
# 65518                          Grand Valley, Colorado, US
# 53115                          Grand Valley, Colorado, US
# 39688            McLaren Vale, South Australia, Australia
# 41929            McLaren Vale, South Australia, Australia
# 119392                           Bolgheri, Tuscany, Italy
# 12845                            Bolgheri, Tuscany, Italy
# 5182       Sta. Rita Hills, Central Coast, California, US
# 115876     Sta. Rita Hills, Central Coast, California, US
# 5704         California, California Other, California, US
# 134423       California, California Other, California, US
# 137728       California, California Other, California, US
# 5703         California, California Other, California, US
# 113674                       Rioja, Northern Spain, Spain
# 134798                       Rioja, Northern Spain, Spain
# 88750        California, California Other, California, US
# 122073       California, California Other, California, US
# 108149                     Chianti Rufina, Tuscany, Italy
# 135978                     Chianti Rufina, Tuscany, Italy
# 25842          Paso Robles, Central Coast, California, US
# 42766          Paso Robles, Central Coast, California, US
# 121925  Arroyo Grande Valley, Central Coast, Californi...
# 143784  Arroyo Grande Valley, Central Coast, Californi...
# 44482                        Rioja, Northern Spain, Spain
# 54538                        Rioja, Northern Spain, Spain
# 78896                              Alsace, Alsace, France
# 102517                             Alsace, Alsace, France
# 102526                             Alsace, Alsace, France
# 78888                              Alsace, Alsace, France
# 34854         El Dorado, Sierra Foothills, California, US
# 28974         El Dorado, Sierra Foothills, California, US
# 135911       Central Coast, Central Coast, California, US
# 115716       Central Coast, Central Coast, California, US
# 115723     Monterey County, Central Coast, California, US
# 114241     Monterey County, Central Coast, California, US
# 71237                             Barolo, Piedmont, Italy
# 96424                             Barolo, Piedmont, Italy
# 93109    Adelaida District, Central Coast, California, US
# 107515   Adelaida District, Central Coast, California, US
# 8794     Adelaida District, Central Coast, California, US
# 74183    Adelaida District, Central Coast, California, US
#
#                               Winery Alcohol Bottle Size Category  \
# 31405                       Ada Nada  14,50%      750 ml      Red
# 53182                       Ada Nada     NaN      750 ml      Red
# 131487  Adega Cooperativa do Cartaxo  14,50%      750 ml      Red
# 140822  Adega Cooperativa do Cartaxo  14,50%      750 ml      Red
# 32483       Adriano Marco & Vittorio  14,00%      750 ml      Red
# 109763      Adriano Marco & Vittorio  14,00%      750 ml      Red
# 81734                  Albert Bichot  13,00%      750 ml      Red
# 82204                  Albert Bichot  13,00%      750 ml      Red
# 6675                  Amador Cellars  15,80%      750 ml      Red
# 81357                 Amador Cellars  16,00%      750 ml      Red
# 65518                         Anemoi  14,20%      750 ml      Red
# 53115                         Anemoi  14,25%      750 ml      Red
# 39688                         Angove  14,00%      750 ml      Red
# 41929                         Angove  14,50%      750 ml      Red
# 119392                         Banfi  13,50%      750 ml      Red
# 12845                          Banfi  14,00%      750 ml      Red
# 5182                          Barden  13,30%      750 ml      Red
# 115876                        Barden  13,30%      750 ml      Red
# 5704                        Barefoot  13,50%      750 ml      Red
# 134423                      Barefoot  13,50%      750 ml      Red
# 137728                      Barefoot  13,50%      750 ml      Red
# 5703                        Barefoot  13,50%      750 ml      Red
# 113674                  Baron De Ley  14,00%      750 ml      Red
# 134798                  Baron De Ley  15,00%      750 ml      Red
# 88750                       Bel Vino  13,20%      750 ml      Red
# 122073                      Bel Vino  13,20%      750 ml      Red
# 108149                       Bellini  12,50%      750 ml      Red
# 135978                       Bellini  13,00%      750 ml      Red
# 25842                        Bianchi  14,50%      750 ml      Red
# 42766                        Bianchi  14,50%      750 ml      Red
# 121925               Bodega de Edgar  14,80%      750 ml      Red
# 143784               Bodega de Edgar  14,80%      750 ml      Red
# 44482                Bodegas Ontañón  13,00%      750 ml      Red
# 54538                Bodegas Ontañón  13,00%      750 ml      Red
# 78896                        Boeckel  13,00%      750 ml      Red
# 102517                       Boeckel  12,00%      750 ml      Red
# 102526                       Boeckel  13,00%      750 ml      Red
# 78888                        Boeckel  14,00%      750 ml      Red
# 34854                         Boeger  15,00%      750 ml      Red
# 28974                         Boeger  15,00%      750 ml      Red
# 135911                    Bonny Doon  14,30%      750 ml      Red
# 115716                    Bonny Doon  14,30%      750 ml      Red
# 115723                    Bonny Doon  14,00%      750 ml      Red
# 114241                    Bonny Doon  14,00%      750 ml      Red
# 71237                       Brandini  14,50%      750 ml      Red
# 96424                       Brandini  14,50%      750 ml      Red
# 93109                  Brecon Estate  14,80%      750 ml      Red
# 107515                 Brecon Estate  14,80%      750 ml      Red
# 8794                   Brecon Estate  14,80%      750 ml      Red
# 74183                  Brecon Estate  14,80%      750 ml      Red
#
#                                                       URL
# 31405   https://www.winemag.com/buying-guide/ada-nada-...
# 53182   https://www.winemag.com/buying-guide/ada-nada-...
# 131487  https://www.winemag.com/buying-guide/adega-coo...
# 140822  https://www.winemag.com/buying-guide/adega-coo...
# 32483   https://www.winemag.com/buying-guide/adriano-m...
# 109763  https://www.winemag.com/buying-guide/adriano-m...
# 81734   https://www.winemag.com/buying-guide/albert-bi...
# 82204   https://www.winemag.com/buying-guide/albert-bi...
# 6675    https://www.winemag.com/buying-guide/amador-ce...
# 81357   https://www.winemag.com/buying-guide/amador-ce...
# 65518   https://www.winemag.com/buying-guide/anemoi-20...
# 53115   https://www.winemag.com/buying-guide/anemoi-20...
# 39688   https://www.winemag.com/buying-guide/angove-20...
# 41929   https://www.winemag.com/buying-guide/angove-20...
# 119392  https://www.winemag.com/buying-guide/banfi-201...
# 12845   https://www.winemag.com/buying-guide/banfi-201...
# 5182    https://www.winemag.com/buying-guide/barden-20...
# 115876  https://www.winemag.com/buying-guide/barden-20...
# 5704    https://www.winemag.com/buying-guide/barefoot-...
# 134423  https://www.winemag.com/buying-guide/barefoot-...
# 137728  https://www.winemag.com/buying-guide/barefoot-...
# 5703    https://www.winemag.com/buying-guide/barefoot-...
# 113674  https://www.winemag.com/buying-guide/baron-de-...
# 134798  https://www.winemag.com/buying-guide/baron-de-...
# 88750   https://www.winemag.com/buying-guide/bel-vino-...
# 122073  https://www.winemag.com/buying-guide/bel-vino-...
# 108149  https://www.winemag.com/buying-guide/bellini-2...
# 135978  https://www.winemag.com/buying-guide/bellini-2...
# 25842   https://www.winemag.com/buying-guide/bianchi-2...
# 42766   https://www.winemag.com/buying-guide/bianchi-2...
# 121925  https://www.winemag.com/buying-guide/bodega-de...
# 143784  https://www.winemag.com/buying-guide/bodega-de...
# 44482   https://www.winemag.com/buying-guide/bodegas-o...
# 54538   https://www.winemag.com/buying-guide/bodegas-o...
# 78896   https://www.winemag.com/buying-guide/boeckel-2...
# 102517  https://www.winemag.com/buying-guide/boeckel-2...
# 102526  https://www.winemag.com/buying-guide/boeckel-2...
# 78888   https://www.winemag.com/buying-guide/boeckel-2...
# 34854   https://www.winemag.com/buying-guide/boeger-20...
# 28974   https://www.winemag.com/buying-guide/boeger-20...
# 135911  https://www.winemag.com/buying-guide/bonny-doo...
# 115716  https://www.winemag.com/buying-guide/bonny-doo...
# 115723  https://www.winemag.com/buying-guide/bonny-doo...
# 114241  https://www.winemag.com/buying-guide/bonny-doo...
# 71237   https://www.winemag.com/buying-guide/brandini-...
# 96424   https://www.winemag.com/buying-guide/brandini-...
# 93109   https://www.winemag.com/buying-guide/brecon-es...
# 107515  https://www.winemag.com/buying-guide/brecon-es...
# 8794    https://www.winemag.com/buying-guide/brecon-es...
# 74183   https://www.winemag.com/buying-guide/brecon-es...

# %%
print('Registros duplicados com mesmo Title e Taster: {}'
      .format( winemag.duplicated(subset=['Title', 'Taster']).sum() ))
print('Registros duplicados com mesmo Title e Rating: {}'
      .format( winemag.duplicated(subset=['Title', 'Rating']).sum() ))
# Out:
# Registros duplicados com mesmo Title e Taster: 303
# Registros duplicados com mesmo Title e Rating: 85

# %%
winemag = winemag.drop_duplicates(subset=['Title'], keep='first')

# %%
winemag.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87260 entries, 0 to 149692
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        87260 non-null  object
#  1   Description  87217 non-null  object
#  2   Taster       84090 non-null  object
#  3   Rating       87260 non-null  int64
#  4   Price        82505 non-null  object
#  5   Designation  63089 non-null  object
#  6   Variety      87259 non-null  object
#  7   Appellation  87260 non-null  object
#  8   Winery       87260 non-null  object
#  9   Alcohol      82906 non-null  object
#  10  Bottle Size  87260 non-null  object
#  11  Category     87260 non-null  object
#  12  URL          87260 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 9.3+ MB

# %% [markdown]
# ### Correções e transformações nos dados
# - Os campos **Alcohol**, **Bottle Size** e **Price** foram convertidos de *object* para respetivamente: *float64*, *int64* e *float64*.

# %%
# Alcohol : transformação em número real substituindo o padrão regex [% ] por ''; e a vírgula pelo ponto.
winemag['Alcohol'] = winemag['Alcohol'].str.replace('[% ]', '', regex=True).str.replace(',', '.').astype('float64')

# %%
# Bottle Size : transformação em número inteiro (em ml) substituindo o padrão regex [mlML ] por ''.
print('=== Bottle Size - Valores - antes ===\n', winemag['Bottle Size'].value_counts())

winemag['Bottle Size'] = winemag['Bottle Size']\
        .str.replace('[mlML ]', '', regex=True).astype('float64')\
        .apply(lambda size: size * 1000 if size <= 3 else size).astype('int64') # Transforma L em ml

print('\n=== Bottle Size - Valores - depois ===\n', winemag['Bottle Size'].value_counts())
# Out:
# === Bottle Size - Valores - antes ===
#  750 ml    86423
# 750ML       663
# 3 L          64
# 1.5 L        39
# 375 ml       24
# 1 L          21
# 500 ml       15
# 250 ml        7
# 187 ml        3
# 1.5L          1
# Name: Bottle Size, dtype: int64
#
# === Bottle Size - Valores - depois ===
#  750     87086
# 3000       64
# 1500       40
# 375        24
# 1000       21
# 500        15
# 250         7
# 187         3
# Name: Bottle Size, dtype: int64

# %%
# Price : transformação em número real substituindo o padrão regex [R$. ] por ''; e a vírgula pelo ponto.
winemag['Price'] = winemag['Price'].str.replace('[R$. ]', '', regex=True).str.replace(',', '.').astype('float64')

# %% [markdown]
# ### Tratamento de dados omissos
# - Foram encontrados valores omissos em 6 colunas e dados os seguintes tratamentos:
#  - **Alcohol**: valores omissos serão tratados após a unificação do dataset com os dados do Vivino, o qual contém também informação sobre teor alcóolico.
#  - **Price**: Os valores omissos foram preenchidos com o preço médio dos vinhos da mesma vinícola (Winery). Para isso foi necessário:
#    - Converter o campo **Price** de *object* para *float64*.
#    - Converter o campo **Bottle Size** de *object* para *float64* e tratar os valores.
#    - Recalcular o preço para que todos os registros estejam no mesmo padrão de uma garrafa de 750ml (tamanho padrão). 5,5% das análises de vinho tinto publicadas no site foram feitas com tamanhos diferentes de garrafa.
#    - Calcular o preço médio por vinícola e aplicar aos registros com preço faltantes.
#    - Após preencher o preço médio por vinícola nos registros de preço faltantes, o número de registros omissos passou de 4755 para 910. Esses últimos valores foram preenchidos com a média geral do preço.
#  - **Variety**: como apenas um registro omisso foi encontrado e não possível identificar a variedade da uva usada para a produção do vinho ao ler o review publicado no site, o registro foi descartado.
#  - **Description**: foram encontrados 43 registros com a descrição do vinho nula; o campo de descrição é parte fundamental para a construção dos modelos de aprendizagem de seção 5 e, portanto, os registros nulos foram descartados.
#  - **Designation**, **Taster**: valores omissos não foram tratados, pois - por trata-se de colunas não aproveitadas para a construção dos modelos preditivos, sendo a coluna **Designation** utilizada na seção 3.4 para cruzamento dos datasets.

# %%
values_missing(winemag)
# Out:
#              percent_missing  rows_missing
# Designation        27.699977         24171
# Price               5.449232          4755
# Alcohol             4.989686          4354
# Taster              3.632821          3170
# Description         0.049278            43
# Variety             0.001146             1

# %%
# Variety
winemag = winemag.dropna(subset=['Variety'])

# %%
# Price: O preço médio é calculado por vinícola e aplicado aos registros de preço faltante.
winemag['Price'] = winemag.groupby('Winery')['Price'].transform(lambda val: val.fillna(val.mean()))

# %%
values_missing(winemag)
# Out:
#              percent_missing  rows_missing
# Designation        27.700295         24171
# Alcohol             4.988597          4353
# Taster              3.631717          3169
# Price               1.042872           910
# Description         0.049279            43

# %%
# Preenche os demais preços nulos do dataset com a média do preço
winemag['Price'] = winemag['Price'].fillna(winemag['Price'].mean())

# %%
# Elimina os registros cuja coluna de descrição seja nula
winemag.dropna(subset=['Description'], inplace=True)

# %%
values_missing(winemag)
# Out:
#              percent_missing  rows_missing
# Designation        27.692167         24152
# Alcohol             4.980737          4344
# Taster              3.610576          3149

# %% [markdown]
# ### Remoção de colunas
# - As colunas **Category** e **URL** foram removidas do dataset. A categoria foi usada para filtrar o dataset para somente vinhos tintos, portanto pode ser removida pois os valores da coluna possuem o mesmo valor. A coluna URL foi gravada para facilitar identificar possíveis erros oriundos da coleta e não terá mais uso de agora em diante.

# %%
winemag = winemag.drop(['Category', 'URL'], axis=1)

# %%
winemag.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87216 entries, 0 to 149692
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        87216 non-null  object
#  1   Description  87216 non-null  object
#  2   Taster       84067 non-null  object
#  3   Rating       87216 non-null  int64
#  4   Price        87216 non-null  float64
#  5   Designation  63064 non-null  object
#  6   Variety      87216 non-null  object
#  7   Appellation  87216 non-null  object
#  8   Winery       87216 non-null  object
#  9   Alcohol      82872 non-null  float64
#  10  Bottle Size  87216 non-null  int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 8.0+ MB

# %% [markdown]
# ### Exportação do Dataset
#
# - Dos 87.574 registros de vinhos tintos inicialmente (após a filtragem), após a tratamento dos registros duplicados e omissos têm-se 87.216 registros.

# %%
# Exporta o dataset para arquivo csv após o tratamento dado até o momento
winemag.to_csv('datasets/winemag_red.csv', index=False, header=True)
